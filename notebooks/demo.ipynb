# %% [markdown]
# # MediLink Demo NotebookThis notebook demonstrates how the MediLink agent responds to user queries.

# %%
from agent import coordinator_agent
from runner import run_chat
print('Run python runner.py locally to test the agent.')
